# %% [markdown]
# # Demo: Customer Support AI Agent
# This notebook demonstrates how the AI agent handles typical customer queries.

# %%
query = 'Where is my order?'
# Replace with actual agent logic
response = 'Your order is on the way and will be delivered within 3-5 days.'
print('Response:', response)
